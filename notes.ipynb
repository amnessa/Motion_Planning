# %% [markdown]
# ## Used notations
#
# The configurations space -> C-space
# q -> denotion of a configuration
# Q -> -> denotion of Configuration space (C in path planning community)
#
# $R(x, y) = {(x' , y' ) | (x − x' )^{2} + ( y − y' )^{ 2} ≤ r^{ 2} }$
#
# > Continue from textbook later.

# %% [markdown]
# ## Holonomic example
#
# ![alt text](images/holonomic_example1.png)
#
# Ground is also a link which makes this as 4 link object
